# %%
from def_fiveTables2 import *
from def_fiveTables import *
import pandas as pd
import numpy as np

# %%
data = pd.read_excel(r"F:\temp\190605\data_JM7.xlsx",sheet_name="Sheet1")

# %%
df = data.copy()

# %%
df.columns
# Out:
# Index(['号码归属地', '销售品编号', '营业厅送货方式', '派单', '派卡', '上门', '首充', '发货量', '签收量',
#        '激活量', '来单量', '所属省', '所属市', '销售品名称', '分类'],
#       dtype='object')

# %%
df_SHCH_province = pd.pivot_table(df, index=[u'分类'], values=['首充'],
                                      aggfunc=[np.sum], fill_value=0,
                                      margins=True, margins_name='合计')

# %%
df["营业厅送货方式"] = df["营业厅送货方式"].fillna("盲投")
df_M = df[df["营业厅送货方式"] == "盲投"]

# %%
df_M_province = df_M.groupby(by=["分类"]).sum()
df_M_province.loc['合计'] = df_M_province.apply(lambda x: x.sum())

# %%
df_M_province["产品订单量占比"] = df_M_province["来单量"].map(
        lambda x: (2 * x) / (sum(df_M_province["来单量"])+0.00001)
    )

# %%
df_M_province["发货率"] = df_M_province["发货量"] / df_M_province["来单量"]

# %%
df_M_province["异常筛查"] = df_M_province["来单量"] - df_M_province["发货量"]

# %%
df_M_province["异常筛查率"] = df_M_province["异常筛查"] / df_M_province["来单量"]

# %%
df_M_province["签收率"] = df_M_province["签收量"] / df_M_province["发货量"]

# %%
df_M_province["未签收量"] = df_M_province["发货量"] - df_M_province["签收量"]

# %%
df_M_province["未签收率"] = df_M_province["未签收量"] / df_M_province["发货量"]

# %%
df_M_province["产品激活量占比"] = df_M_province["激活量"].map(
        lambda x: (2 * x) / (sum(df_M_province["激活量"])+ 0.00001)
    )

# %%
df_M_province["激活率"] = df_M_province["激活量"] / df_M_province["签收量"]

# %%
df_M_province["未激活量"] = df_M_province["签收量"] - df_M_province["激活量"]

# %%
df_M_province["未激活率"] = df_M_province["未激活量"] / df_M_province["签收量"]

# %%
df_M_province["发货激活率"] = df_M_province["激活量"] / df_M_province["发货量"]

# %%
df_M_province["产品首充量占比"] = df_M_province["首充"].map(
        lambda x: (2 * x) / (sum(df_M_province["首充"]) + 0.00001)
    )

# %%
df_M_province["首充率"] = df_M_province["首充"] / df_M_province["发货量"]

# %%
df_M_province["全量首充"] = df_SHCH_province

# %%
df_M_province = df_M_province.reset_index('分类')

# %%
df_M_province.columns
# Out:
# Index(['所属省', '派单', '派卡', '上门', '首充', '发货量', '签收量', '激活量', '来单量', '省份订单量占比',
#        '发货率', '异常筛查', '异常筛查率', '签收率', '未签收量', '未签收率', '省份激活量占比', '激活率', '未激活量',
#        '未激活率', '发货激活率', '省份首充量占比', '首充率', '全量首充'],
#       dtype='object')

# %%
df_M_province2 = df_M_province[["分类","来单量",
                                    "省份订单量占比",
                                    "发货量",
                                    "发货率",
                                    "异常筛查",
                                    "异常筛查率",
                                    "签收量",
                                    "签收率",
                                    "未签收量",
                                    "未签收率",
                                    "激活量",
                                    "省份激活量占比",
                                    "激活率","未激活量","未激活率","发货激活率",
                                    "首充",
# 9   0.957447    10  ...    155  0.042005  0.688889    70  0.311111  0.659574
# 10  1.000000     0  ...     44  0.011924  0.745763    15  0.254237  0.745763
# 11  0.986733     8  ...    450  0.121951  0.756303   145  0.243697  0.746269
# 12  0.900585    17  ...    102  0.027642  0.662338    52  0.337662  0.596491
# 13  0.792793    46  ...    145  0.039295  0.823864    31  0.176136  0.653153
# 14  0.714286    40  ...     95  0.025745  0.950000     5  0.050000  0.678571
# 15  0.955556     4  ...     61  0.016531  0.709302    25  0.290698  0.677778
# 16  1.000000     0  ...    121  0.032791  0.720238    47  0.279762  0.720238
# 17  0.976834    12  ...    352  0.095393  0.695652   154  0.304348  0.679537
# 18  1.000000     0  ...    143  0.038753  0.764706    44  0.235294  0.764706
# 19  1.000000     0  ...     13  0.003523  0.684211     6  0.315789  0.684211
# 20  0.994595     1  ...    129  0.034959  0.701087    55  0.298913  0.697297
# 21  0.947531    17  ...    229  0.062060  0.745928    78  0.254072  0.706790
# 22  0.973510     4  ...    100  0.027100  0.680272    47  0.319728  0.662252
# 23  0.987952     1  ...     60  0.016260  0.731707    22  0.268293  0.722892
# 24  0.866667     2  ...     10  0.002710  0.769231     3  0.230769  0.666667
# 25  0.953488     6  ...     81  0.021951  0.658537    42  0.341463  0.627907
# 26  1.000000     0  ...     78  0.021138  0.644628    43  0.355372  0.644628
# 27  1.000000     0  ...     54  0.014634  0.635294    31  0.364706  0.635294
# 28  1.000000     0  ...    123  0.033333  0.719298    48  0.280702  0.719298
# 29  1.000000     0  ...     17  0.004607  0.772727     5  0.227273  0.772727
# 30  0.920455     7  ...     58  0.015718  0.716049    23  0.283951  0.659091
# 31  0.955291   237  ...   3690  1.000000  0.728673  1374  0.271327  0.696095
#
#      首充   省份首充量占比       首充率  全量首充
# 0     2  0.009852  0.023529    36
# 1     5  0.024631  0.018939    30
# 2     2  0.009852  0.025641     6
# 3    19  0.093596  0.031720    47
# 4     2  0.009852  0.015385    13
# 5    11  0.054187  0.068323    36
# 6     5  0.024631  0.125000    16
# 7     0  0.000000  0.000000     8
# 8     8  0.039409  0.058394    15
# 9     8  0.039409  0.034043    37
# 10    7  0.034483  0.118644    24
# 11   18  0.088670  0.029851   151
# 12    8  0.039409  0.046784    27
# 13    0  0.000000  0.000000     0
# 14   12  0.059113  0.085714    42
# 15    7  0.034483  0.077778    16
# 16    3  0.014778  0.017857    14
# 17   12  0.059113  0.023166    63
# 18   11  0.054187  0.058824    36
# 19    0  0.000000  0.000000     2
# 20    8  0.039409  0.043243    33
# 21   22  0.108374  0.067901    38
# 22    2  0.009852  0.013245     4
# 23    6  0.029557  0.072289    36
# 24    0  0.000000  0.000000     0
# 25    2  0.009852  0.015504    10
# 26    4  0.019704  0.033058    35
# 27    1  0.004926  0.011765    13
# 28   16  0.078818  0.093567    43
# 29    0  0.000000  0.000000     5
# 30    2  0.009852  0.022727    14
# 31  203  1.000000  0.038295   850
#
# [32 rows x 21 columns]
