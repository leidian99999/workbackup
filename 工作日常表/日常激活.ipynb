# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_excel(r"F:\temp\190625/0623.xlsx",sheet_name = "Sheet1")
biaoka = pd.read_excel(r"G:\work\daily\DataShow\产品标卡.xlsx")

# %%
# 分列
split1 = pd.DataFrame((x.split('/') for x in data['号码归属地']),index=data.index,columns=['所属省','所属市'])
data = pd.merge(data, split1, left_index=True, right_index=True)

# %%
data_New = pd.merge(data, biaoka, how="left", on="销售品编号")

# %%
data_New["是否线下模式"] = data_New["是否线下模式"].fillna("否")

# %%
df = pd.pivot_table(data_New, index=[u'所属省'], values=['订单编号'],columns=[u'是否线下模式'],
                                      aggfunc=[len], fill_value=0,
                                      margins=True, margins_name='合计')
df
# Out:
#            len
#           订单编号
# 是否线下模式       否     是     合计
# 所属省
# 上海市         14   460    474
# 云南省         45   154    199
# 内蒙古自治区      20   126    146
# 北京         120   552    672
# 吉林省         21   172    193
# 四川省         32   298    330
# 天津市          5    93     98
# 宁夏回族自治区      3    67     70
# 安徽省         14   267    281
# 山东省         45  1020   1065
# 广东省        171  1631   1802
# 广西壮族自治区     33   236    269
# 新疆维吾尔自治区    73     0     73
# 江苏省         40   664    704
# 江西省         44   133    177
# 河北省         32   525    557
# 河南省        103   628    731
# 浙江省         48   530    578
# 海南省          7    46     53
# 湖北省         73   411    484
# 湖南省         71   409    480
# 甘肃省         21   144    165
# 福建省         28   187    215
# 西藏自治区        5     0      5
# 贵州省         31   146    177
# 辽宁省         30   318    348
# 重庆市          8   130    138
# 陕西省         48   309    357
# 青海省          6    23     29
# 黑龙江省        25   220    245
# 合计        1216  9899  11115

# %%
df = df.reset_index()
df
# Out:
#              所属省   len
#                   订单编号
# 是否线下模式               否     是     合计
# 0            上海市    14   460    474
# 1            云南省    45   154    199
# 2         内蒙古自治区    20   126    146
# 3             北京   120   552    672
# 4             合计  1216  9899  11115
# 5            吉林省    21   172    193
# 6            四川省    32   298    330
# 7            天津市     5    93     98
# 8        宁夏回族自治区     3    67     70
# 9            安徽省    14   267    281
# 10           山东省    45  1020   1065
# 11           广东省   171  1631   1802
# 12       广西壮族自治区    33   236    269
# 13      新疆维吾尔自治区    73     0     73
# 14           江苏省    40   664    704
# 15           江西省    44   133    177
# 16           河北省    32   525    557
# 17           河南省   103   628    731
# 18           浙江省    48   530    578
# 19           海南省     7    46     53
# 20           湖北省    73   411    484
# 21           湖南省    71   409    480
# 22           甘肃省    21   144    165
# 23           福建省    28   187    215
# 24         西藏自治区     5     0      5
# 25           贵州省    31   146    177
# 26           辽宁省    30   318    348
# 27           重庆市     8   130    138
# 28           陕西省    48   309    357
# 29           青海省     6    23     29
# 30          黑龙江省    25   220    245

# %%
df = df.reset_index
# Out:
# MultiIndex(levels=[['len'], ['订单编号'], ['合计', '否', '是']],
#            labels=[[0, 0, 0], [0, 0, 0], [1, 2, 0]],
#            names=[None, None, '是否线下模式'])

# %%
df["len"]["订单编号"]["是"]
# Out:
# 所属省
# 上海市          460
# 云南省          154
# 内蒙古自治区       126
# 北京           552
# 吉林省          172
# 四川省          298
# 天津市           93
# 宁夏回族自治区       67
# 安徽省          267
# 山东省         1020
# 广东省         1631
# 广西壮族自治区      236
# 新疆维吾尔自治区       0
# 江苏省          664
# 江西省          133
# 河北省          525
# 河南省          628
# 浙江省          530
# 海南省           46
# 湖北省          411
# 湖南省          409
# 甘肃省          144
# 福建省          187
# 西藏自治区          0
# 贵州省          146
# 辽宁省          318
# 重庆市          130
# 陕西省          309
# 青海省           23
# 黑龙江省         220
# 合计          9899
# Name: 是, dtype: int64
